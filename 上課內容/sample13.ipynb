# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt
data = [-1, -4.3, 15, 21, 31]
plt.figure(num='我的第一個圖表',figsize=(8, 5))
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import matplotlib.pyplot as plt
plt.figure(num=5,)
x = [1, 2, 3, 4, 5]
y1 = [1, 2, 5, 6, 7]
y2 = [4, 5, 6, 12, 24]
plt.plot(x, y1, x, y2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x7ffaea674e90>,
#  <matplotlib.lines.Line2D at 0x7ffaea6b9150>]
