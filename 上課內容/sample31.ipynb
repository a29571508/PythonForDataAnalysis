# %%
import certifi
import urllib3

json_url = "https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
response = http.request('GET', json_url)
if response.status == 200:
    print("下載成功")
    print(response.data)
else:
    print("下載失敗")
# Out:
# 下載成功
# b'{\n "cwbopendata": {\n  "@xmlns": "urn:cwb:gov:tw:cwbcommon:0.1",\n  "identifier": "76621f2b-53c4-4796-afbc-a234b2ba176b",\n  "sender": "weather@cwb.gov.tw",\n  "sent": "2020-06-22T20:58:05+08:00",\n  "status": "Actual",\n  "msgType": "Issue",\n  "dataid": "CWB_A0001",\n  "scope": "Public",\n  "dataset": null,\n  "location": [\n   {\n    "lat": "25.035950",\n    "lon": "121.611456",\n    "lat_wgs84": "25.0341638888889",\n    "lon_wgs84": "121.619680555556",\n    "locationName": "\xe5\x9c\x8b\xe4\xb8\x89\xe5\x8d\x97\xe6\xb7\xb1\xe8\xb7\xaf\xe4\xba\xa4\xe6\xb5\x81\xe9\x81\x93",\n    "stationId": "CM0010",\n    "time": {\n     "obsTime": "2020-06-22T20:00:00+08:00"\n    },\n    "weatherElement": [\n     {\n      "elementName": "ELEV",\n      "elementValue": {\n       "value": "68.0"\n      }\n     },\n     {\n      "elementName": "WDIR",\n      "elementValue": {\n       "value": "209"\n      }\n     },\n     {\n      "elementName": "WDSD",\n      "elementValue": {\n       "value": "0.9"\n      }\n     },\n     {\n      "elementName": "TEMP",\n      "elementValue": {\n       "value": "30.6"\n      }\n     },\n     {\n      "elementName": "HUMD",\n      "elementValue": {\n       "value": "0.61"\n      }\n     },\n     {\n      "elementName": "PRES",\n      "elementValue": {\n       "value": "999.0"\n      }\n     },\n     {\n      "elementName": "H_24R",\n      "elementValue": {\n       "value": "0.0"\n      }\n     },\n     {\n      "elementName": "H_FX",\n      "elementValue": {\n       "value": "-99"\n      }\n     },\n     {\n      "elementName": "H_XD",\n      "elementValue": {\n       "value": "-99"\n      }\n     },\n     {\n      "elementName": "H_FXT",\n      "elementValue": {\n       "value": "-99"\n      }\n     },\n     {\n      "elementName": "D_TX",\n      "elementValue": {\n       "value": "35.60"\n      }\n     },\n     {\n      "elementName": "D_TXT",\n      "elementValue": {\n       "value": "2020-06-22T12:30:00+08:00"\n      }\n     },\n     {\n      "elementName": "D_TN",\n      "elementValue": {\n       "value": "25.70"\n      }\n     },\n     {\n      "elementName": "D_TNT",\n      "elementValue": {\n       "value": "2020-06-22T05:30:00+08:00"\n      }\n     }\n    ],\n    "parameter": [\n     {\n      "parameterName": "CITY",\n      "parameterValue": "\xe8\x87\xba\xe5\x8c\x97\xe5\xb8\x82"\n     },\n     {\n      "parameterName": "CITY_SN",\n      "parameterValue": "01"\n     },\n     {\n      "parameterName": "TOWN",\n      "parameterValue": "\xe5\x8d\x97\xe6\xb8\xaf\xe5\x8d\x80"\n     },\n     {\n      "parameterName": "TOWN_SN",\n      "parameterValue": "035"\n     }\n    ]\n   },\n   {\n    "lat": "24.091036",\n    "lon": "120.428836",\n    "lat_wgs84": "24.0892916666667",\n    "lon_wgs84": "120.436986111111",\n    "locationName": "\xe6\xb0\xb4\xe8\xa9\xa6\xe6\x89\x80\xe9\xb9\xbf\xe6\xb8\xaf",\n    "stationId": "CM0110",\n    "time": {\n     "obsTime": "2020-06-22T20:00:00+08:00"\n    },\n    "weatherElement": [\n     {\n      "elementName": "ELEV",\n      "elementValue": {\n       "value": "7.0"\n      }\n     },\n     {\n      "elementName": "WDIR",\n      "elementValue": {\n       "value": "221"\n      }\n     },\n     {\n      "elementName": "WDSD",\n      "elementValue": {\n       "value": "1.6"\n      }\n     },\n     {\n      "elementName": "TEMP",\n      "elementValue": {\n       "value": "29.7"\n      }\n     },\n     {\n      "elementName": "HUMD",\n      "elementValue": {\n       "value": "0.72"\n      }\n     },\n     {\n      "elementName": "PRES",\n      "elementValue": {\n       "value": "1006.9"\n      }\n     },\n     {\n      "elementName": "H_24R",\n      "elementValue": {\n       "value": "-99"\n      }\n     },\n     {\n      "elementName": "H_FX",\n      "elementValue": {\n       "value": "-99"\n      }\n     },\n     {\n      "elementName": "H_XD",\n      "elementValue": {\n       "value": "-99"\n      }\n     },\n     {\n      "elementName": "H_FXT",\n      "elementValue": {\n     ...
