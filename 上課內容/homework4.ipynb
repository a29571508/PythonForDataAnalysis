# %%
import pandas as pd
import numpy as np

result = pd.read_csv('各鄉鎮市區人口密度.csv')
result.columns = result.loc[0]
newResult=result.loc[1:368,['區域別','年底人口數','土地面積','人口密度']]

# %%
newResult = newResult.reset_index().drop('index',axis=1)

# %%
def getState(x):
    return x[:3]

newResult['縣市']=newResult['區域別'].map(getState)
newResult['區域別'] = newResult['區域別'].map(lambda x: x[3:])
newResult.set_index(['縣市', '區域別'],inplace=True)

# %%
newResult
# Out:
# 0         年底人口數     土地面積   人口密度
# 縣市  區域別
# 新北市 板橋區  551480  23.1373  23835
#     三重區  387484   16.317  23747
#     中和區  413590   20.144  20532
#     永和區  222585   5.7138  38956
#     新莊區  416524  19.7383  21102
# ...         ...      ...    ...
# 金門縣 烏坵鄉     685      1.2    571
# 連江縣 南竿鄉    7544     10.4    725
#     北竿鄉    2360      9.9    238
#     莒光鄉    1624      4.7    346
#     東引鄉    1352      3.8    356
#
# [368 rows x 3 columns]
