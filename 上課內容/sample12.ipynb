# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
data = [-1, -4.3, 15, 21, 31]
plt.figure(num=123,figsize=(8.5,5.0))
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="850">
