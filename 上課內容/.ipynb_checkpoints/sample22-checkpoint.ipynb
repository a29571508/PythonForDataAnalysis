# %%
import csv
import pandas as pd

with open('各鄉鎮市區人口密度.csv','r',encoding='utf-8') as file:
    reader = csv.reader(file)
    '''
    resultList = list();    
    for item  in reader:
        if item[0] == '統計年' or item[0] == '106':
            resultList.append(item)
    '''
    resultList = [item for item in reader if item[0] == '統計年' or item[0] == '106']
    title=resultList.pop(0)
    #print(title)
    #print(resultList)
    

dataFrame=pd.DataFrame(resultList,columns=title)
dataFrame.reindex(columns=['統計年','區域別','年底人口數','土地面積'])
# Out:
#      統計年     區域別   年底人口數     土地面積
# 0    106  新北市板橋區  551480  23.1373
# 1    106  新北市三重區  387484   16.317
# 2    106  新北市中和區  413590   20.144
# 3    106  新北市永和區  222585   5.7138
# 4    106  新北市新莊區  416524  19.7383
# ..   ...     ...     ...      ...
# 365  106  連江縣北竿鄉    2360      9.9
# 366  106  連江縣莒光鄉    1624      4.7
# 367  106  連江縣東引鄉    1352      3.8
# 368  106    東沙群島      …      2.38
# 369  106    南沙群島      …    0.5045
#
# [370 rows x 4 columns]
