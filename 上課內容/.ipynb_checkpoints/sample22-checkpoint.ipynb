# %%
import json
import pandas as pd

with open('新北市公共自行車租賃系統.json', 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)
    if data['success']:
        records = data['result']['records']
        #print(records)
    else:
        print('讀取失敗')

#columns是要選出想要的欄位
dataFrame = pd.DataFrame(records,columns=['sno', 'sarea', 'sna', 'ar', 'tot', 'sbi', 'bemp', 'lat', 'lng'])

#columns改變欄位的名稱
dataFrame.columns = ['編號', '區域', '站名', '地址', '全部數量', '可借', '可還', '緯度', '經度']
# Out:
#        編號   區域               站名                      地址 全部數量  可借  可還  \
# 583  1679  五股區             芳洲八路            芳洲八路152號(對面)   30  13  16
# 584  1680  三重區        後竹圍市民活動中心         後竹圍街175巷18號(對面)   32   8  24
# 585  1681  林口區         林口國民運動中心  文化二路二段369號(文化二路二段側人行道)   40  27  12
# 586  1683  深坑區            深坑松柏街              松柏街24號(對面)   34   7  27
# 587  1684  金山區             金美國小            仁愛路37-5號(對面)   36  17  19
# 588  1685  金山區            金山八德街              八德街24號(對面)   38  10  27
# 589  1687  新店區          寶橋路78巷口    寶橋路78巷10號(旁高速公路橋下空間)   44  21  21
# 590  1688  鶯歌區             鳳福公園            鳳吉一街186號(對面)   40  14  25
# 591  1690  中和區             漳和國中              廣福路30號(對面)   50  17  33
# 592  1693  林口區  國立師範大學林口校區(測試站)      仁愛路1段2號(校門前自行車停車區)   16   8   8
# 593  1695  汐止區      長安橋(吉祥街12巷)             吉祥街12巷2號(旁)   34  11  23
# 594  1696  三重區       三重商工(後竹圍街)  中正北路165巷53號(後竹圍街路側停車格)   36  23  13
# 595  1698  板橋區  浮洲合宜住宅(合宜合安一路口)      合宜路/合安一路(東南側機車停車場)   50   7  43
# 596  1700  中和區           德光莒光路口               德光路12號(前)   38  18  19
# 597  1701  新莊區            捷運幸福站        思源路292號(幸福東路側廣場)   54  16  35
# 598  1702  五股區         成泰路4段22巷         成泰路4段22巷29號(對面)   32  13  19
# 599  1706  金山區              中角灣            海興路174-1號(旁)   28  14  14
# 600  1709  中和區            捷運景安站             景平路486號(對面)   82  33  49
# 601  1710  林口區           林口婦幼公園         文化一路一段146號(旁公園)   30   9  19
# 602  1713  板橋區             埤墘公園          萬板路108號(前公園路側)   30  12  17
#
#             緯度          經度
# 583  25.088800  121.446370
# 584  25.072460  121.485760
# 585  25.086010  121.380930
# 586  25.010960  121.638520
# 587  25.219730  121.636330
# 588  25.223650  121.634690
# 589  24.973680  121.547600
# 590  24.975720  121.329380
# 591  25.002410  121.505000
# 592  25.068040  121.397950
# 593  25.080330  121.668460
# 594  25.070310  121.479760
# 595  24.998490  121.448630
# 596  25.004590  121.471340
# 597  25.049580  121.460520
# 598  25.108260  121.455960
# 599  25.239000  121.632340
# 600  24.993520  121.504720
# 601  25.072310  121.377520
# 602  25.023320  121.474220
