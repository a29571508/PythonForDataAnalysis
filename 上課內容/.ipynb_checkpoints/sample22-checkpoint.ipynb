# %%
import csv
import pandas as pd

with open('各鄉鎮市區人口密度.csv','r',encoding='utf-8') as file:
    reader = csv.reader(file)
    '''
    resultList = list();    
    for item  in reader:
        if item[0] == '統計年' or item[0] == '106':
            resultList.append(item)
    '''
    resultList = [item for item in reader if item[0] == '統計年' or item[0] == '106']
    title=resultList.pop(0)
    #print(title)
    #print(resultList)
    

dataFrame=pd.DataFrame(resultList,columns=title)
dataFrame[-20:]
# Out:
#      統計年     區域別   年底人口數     土地面積  人口密度
# 350  106  基隆市中山區   47908  10.5238  4552
# 351  106  基隆市安樂區   82358   18.025  4569
# 352  106  基隆市信義區   52035  10.6706  4876
# 353  106   新竹市東區  212553  33.5768  6330
# 354  106   新竹市北區  150636  15.7267  9578
# 355  106  新竹市香山區   77943  54.8491  1421
# 356  106   嘉義市東區  122103  30.1556  4049
# 357  106   嘉義市西區  147295    29.87  4931
# 358  106  金門縣金城鎮   43285   21.713  1994
# 359  106  金門縣金湖鎮   29413   41.696   705
# 360  106  金門縣金沙鎮   20535    41.19   499
# 361  106  金門縣金寧鄉   30838   29.854  1033
# 362  106  金門縣烈嶼鄉   12700   16.003   794
# 363  106  金門縣烏坵鄉     685      1.2   571
# 364  106  連江縣南竿鄉    7544     10.4   725
# 365  106  連江縣北竿鄉    2360      9.9   238
# 366  106  連江縣莒光鄉    1624      4.7   346
# 367  106  連江縣東引鄉    1352      3.8   356
# 368  106    東沙群島      …      2.38    …
# 369  106    南沙群島      …    0.5045    …
