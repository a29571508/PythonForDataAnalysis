# %%
import pandas as pd
import numpy as np
#排序索引
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
obj.sort_index(axis=0)
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                    index = ['three', 'one'],
                    columns=['d', 'a', 'b', 'c'])
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index(axis=1)
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index(axis=1,ascending=False)
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
#排序內容
#sort_values()
obj = pd.Series([4, 7, -3, 2])
obj
# Out:
# 0    4
# 1    7
# 2   -3
# 3    2
# dtype: int64

# %%
obj.sort_values()
# Out:
# 2   -3
# 3    2
# 0    4
# 1    7
# dtype: int64

# %%
frame = pd.DataFrame({'b':[4, 7, -3, 2], 'a':[0, 1, 0, 1]})
frame
# Out:
#    b  a
# 0  4  0
# 1  7  1
# 2 -3  0
# 3  2  1

# %%
frame.sort_values(by='a')
# Out:
#    b  a
# 0  4  0
# 2 -3  0
# 1  7  1
# 3  2  1

# %%
#排名
obj = pd.Series([7, -5, 7, 4, 2, 0, 4])
obj=obj.rank(method='first')
obj.sort_values()
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 3    4.0
# 6    5.0
# 0    6.0
# 2    7.0
# dtype: float64

# %%
obj = pd.Series([7, -5, 7, 4, 2, 0, 4])
obj.rank(method='first',ascending=False)
# Out:
# 0    1.0
# 1    7.0
# 2    2.0
# 3    3.0
# 4    5.0
# 5    6.0
# 6    4.0
# dtype: float64

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#python的Dictionary
data = {'年廣告費投入':[12.5, 15.3, 23.2, 26.4, 33.5, 34.4, 39.4, 45.2, 55.4, 60.9],
            '月均銷售額':[21.2, 23.9, 32.9, 34.1, 42.5, 43.2, 49.0, 52.8, 59.4, 63.5]}
#dataFrame
dataFrame = pd.DataFrame(data,index=[2020,2019,2018,2017,2016,2015,2014,2013,2012,2011])
dataFrame
# Out:
#       年廣告費投入  月均銷售額
# 2020    12.5   21.2
# 2019    15.3   23.9
# 2018    23.2   32.9
# 2017    26.4   34.1
# 2016    33.5   42.5
# 2015    34.4   43.2
# 2014    39.4   49.0
# 2013    45.2   52.8
# 2012    55.4   59.4
# 2011    60.9   63.5

# %%
dataFrame1 = dataFrame.sort_index()
dataFrame1
# Out:
#       年廣告費投入  月均銷售額
# 2011    60.9   63.5
# 2012    55.4   59.4
# 2013    45.2   52.8
# 2014    39.4   49.0
# 2015    34.4   43.2
# 2016    33.5   42.5
# 2017    26.4   34.1
# 2018    23.2   32.9
# 2019    15.3   23.9
# 2020    12.5   21.2

# %%
dataFrame1.values
# Out:
# array([[60.9, 63.5],
#        [55.4, 59.4],
#        [45.2, 52.8],
#        [39.4, 49. ],
#        [34.4, 43.2],
#        [33.5, 42.5],
#        [26.4, 34.1],
#        [23.2, 32.9],
#        [15.3, 23.9],
#        [12.5, 21.2]])

# %%
plt.plot(dataFrame1.values, 'ko--')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
correlation = dataFrame1['年廣告費投入'].corr(dataFrame1['月均銷售額'])
#相關係數
correlation
# Out:
# 0.9941983762371882

# %%
import pandas_datareader.data as web
web.get_data_yahoo('AAPL')
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2015-06-05  129.690002  128.360001  129.500000  128.649994  35626800.0
# 2015-06-08  129.210007  126.830002  128.899994  127.800003  52674800.0
# 2015-06-09  128.080002  125.620003  126.699997  127.419998  56075400.0
# 2015-06-10  129.339996  127.849998  127.919998  128.880005  39087300.0
# 2015-06-11  130.179993  128.479996  129.179993  128.589996  35390900.0
# ...                ...         ...         ...         ...         ...
# 2020-05-28  323.440002  315.630005  316.769989  318.250000  33390200.0
# 2020-05-29  321.149994  316.470001  319.250000  317.940002  38399500.0
# 2020-06-01  322.350006  317.209991  317.750000  321.850006  20197800.0
# 2020-06-02  323.440002  318.929993  320.750000  323.339996  21910700.0
# 2020-06-03  326.200012  322.299988  324.660004  325.119995  26101800.0
#
#              Adj Close
# Date
# 2015-06-05  118.564957
# 2015-06-08  117.781601
# 2015-06-09  117.431381
# ...

# %%
all_data = {ticker:web.get_data_yahoo(ticker) for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}
all_data
# Out:
# {'AAPL':                   High         Low        Open       Close      Volume  \
#  Date
#  