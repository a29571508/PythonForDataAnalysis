# %%
import pandas as pd
objs = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
objs
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
#reindex()實體方法->重新改變索引
#reindex()重新排序索引或保留想要的索引
objs.reindex(['a', 'b', 'c', 'd'])
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# dtype: float64

# %%
objs.reindex(['a', 'b', 'c'])
# Out:
# a   -5.3
# b    7.2
# c    3.6
# dtype: float64

# %%
#DataFrame可以使用reindex()改變列或欄的排序或保留想要的索引
import numpy as np
#np.arange(9).reshape(3,3)使用ndarray來建立DataFrame
frame = pd.DataFrame(np.arange(9).reshape(3,3),index=['a','c','d'],columns=['台北', '台中', '高雄'])
frame
# Out:
#    台北  台中  高雄
# a   0   1   2
# c   3   4   5
# d   6   7   8

# %%
frame.reindex(['a', 'd', 'c'])
# Out:
#    台北  台中  高雄
# a   0   1   2
# d   6   7   8
# c   3   4   5

# %%
frame.reindex(['a', 'c'])
# Out:
#    台北  台中  高雄
# a   0   1   2
# c   3   4   5

# %%
#reindex(columns=[])改變欄位的索引
frame.reindex(columns=['台北', '高雄', '台中'])
# Out:
#    台北  高雄  台中
# a   0   2   1
# c   3   5   4
# d   6   8   7

# %%
#reindex(columns=[])保留欄位的索引
frame.reindex(columns=['台北', '台中'])
# Out:
#    台北  台中
# a   0   1
# c   3   4
# d   6   7

# %%
#drop()實體方法 --> 預設移除列,drop(,axis=1)
data = pd.DataFrame(np.arange(16).reshape(4,4),
                   index=['台北','台中', '台南', '高雄'],
                   columns=['one', 'two', 'three', 'four'])
data
# Out:
#     one  two  three  four
# 台北    0    1      2     3
# 台中    4    5      6     7
# 台南    8    9     10    11
# 高雄   12   13     14    15

# %%
data.drop(['台北', '台中'])
# Out:
#     one  two  three  four
# 台南    8    9     10    11
# 高雄   12   13     14    15

# %%
data.drop(['one', 'two'],axis=1)
# Out:
#     three  four
# 台北      2     3
# 台中      6     7
# 台南     10    11
# 高雄     14    15

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                   index=['台北','台中','台南', '高雄'],
                   columns=['one', 'two', 'three', 'four'])
data
# Out:
#     one  two  three  four
# 台北    0    1      2     3
# 台中    4    5      6     7
# 台南    8    9     10    11
# 高雄   12   13     14    15

# %%
data[['one', 'two', 'three']]
# Out:
#     one  two  three
# 台北    0    1      2
# 台中    4    5      6
# 台南    8    9     10
# 高雄   12   13     14

# %%
data[:2]
# Out:
#     one  two  three  four
# 台北    0    1      2     3
# 台中    4    5      6     7

# %%
data[:1]
# Out:
#     one  two  three  four
# 台北    0    1      2     3

# %%
data[-2:]
# Out:
#     one  two  three  four
# 台南    8    9     10    11
# 高雄   12   13     14    15

# %%
#bs = pd.Series([True, False, False, False]) 不是任意的Series就可以過濾
#data[bs]
data
# Out:
#     one  two  three  four
# 台北    0    1      2     3
# 台中    4    5      6     7
# 台南    8    9     10    11
# 高雄   12   13     14    15

# %%
filterData=data['four'] > 10
data[filterData]
# Out:
#     one  two  three  four
# 台南    8    9     10    11
# 高雄   12   13     14    15

# %%
data < 10
# Out:
#       one    two  three   four
# 台北   True   True   True   True
# 台中   True   True   True   True
# 台南   True   True  False  False
# 高雄  False  False  False  False

# %%
data[data < 10] = 0
data
# Out:
#     one  two  three  four
# 台北    0    0      0     0
# 台中    0    0      0     0
# 台南    0    0     10    11
# 高雄   12   13     14    15

# %%
#實體屬性loc[],iloc[]
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                   index=['台北','台中','台南', '高雄'],
                   columns=['one', 'two', 'three', 'four'])
data
# Out:
#     one  two  three  four
# 台北    0    1      2     3
# 台中    4    5      6     7
# 台南    8    9     10    11
# 高雄   12   13     14    15

# %%
data.loc['台北',['two', 'three']]
# Out:
# two      1
# three    2
# Name: 台北, dtype: int64

# %%
data.iloc[0,[1, 2]]
# Out:
# two      1
# three    2
# Name: 台北, dtype: int64

# %%
data.iloc[2]
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: 台南, dtype: int64

# %%
data.loc['台南']
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: 台南, dtype: int64

# %%
import pandas as pd
dataFrame = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame
# Out:
#     statistic_yyy                                            site_id  \
# 0             統計年                                                區域別
# 1             106                                             新北市板橋區
# 2             106                                             新北市三重區
# 3             106                                             新北市中和區
# 4             106                                             新北市永和區
# ..            ...                                                ...
# 371           NaN                                                NaN
# 372           NaN                           說明：1.人口密度係指每單位土地面積內之人口數。
# 373           NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374           NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
# 375           NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。
#
#     people_total     area population_density
# 0          年底人口數     土地面積               人口密度
# 1         551480  23.1373              23835
# 2         387484   16.317              23747
# 3         413590   20.144              20532
# 4         222585   5.7138              38956
# ..           ...      ...                ...
# 371          NaN      NaN                NaN
# 372          NaN      NaN                NaN
# 373          NaN      NaN                NaN
# 374          NaN      NaN                NaN
# 375          NaN      NaN                NaN
#
# [376 rows x 5 columns]

# %%
dataFrame.dtypes
# Out:
# statistic_yyy         object
# site_id               object
# people_total          object
# area                  object
# population_density    object
# dtype: object

# %%
dataFrame.shape
# Out:
# (376, 5)

# %%
dataFrame[:1]
# Out:
#   statistic_yyy site_id people_total  area population_density
# 0           統計年     區域別        年底人口數  土地面積               人口密度

# %%
dataFrame.loc[0]
# Out:
# statistic_yyy           統計年
# site_id                 區域別
# people_total          年底人口數
# area                   土地面積
# population_density     人口密度
# Name: 0, dtype: object

# %%
dataFrame.columns = dataFrame.loc[0]
dataFrame
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 0     人口密度
# 1    23835
# 2    23747
# 3    20532
# 4    38956
# ..     ...
# 371    NaN
# 372    NaN
# 373    NaN
# 374    NaN
# 375    NaN
#
# [376 rows x 5 columns]

# %%
dataFrame=dataFrame.drop(0)

# %%
dataFrame
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# 5    106                                             新北市新莊區  416524  19.7383
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 1    23835
# 2    23747
# 3    20532
# 4    38956
# 5    21102
# ..     ...
# 371    NaN
# 372    NaN
# 373    NaN
# 374    NaN
# 375    NaN
#
# [375 rows x 5 columns]

# %%
dataFrame[-30:]
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 346  106                                             澎湖縣七美鄉    3856   6.9868
# 347  106                                             基隆市中正區   52163  10.2118
# 348  106                                             基隆市七堵區   53972  56.2659
# 349  106                                             基隆市暖暖區   38708  22.8283
# 350  106                                             基隆市仁愛區   44314   4.2335
# 351  106                                             基隆市中山區   47908  10.5238
# 352  106                                             基隆市安樂區   82358   18.025
# 353  106                                             基隆市信義區   52035  10.6706
# 354  106                                              新竹市東區  212553  33.5768
# 355  106                                              新竹市北區  150636  15.7267
# 356  106                                             新竹市香山區   77943  54.8491
# 357  106                                              嘉義市東區  122103  30.1556
# 358  106                                              嘉義市西區  147295    29.87
# 359  106                                             金門縣金城鎮   43285   21.713
# 360  106                                             金門縣金湖鎮   29413   41.696
# 361  106                                             金門縣金沙鎮   20535    41.19
# 362  106                                             金門縣金寧鄉   30838   29.854
# 363  106                                             金門縣烈嶼鄉   12700   16.003
# 364  106                                             金門縣烏坵鄉     685      1.2
# 365  106                                             連江縣南竿鄉    7544     10.4
# 366  106                                             連江縣北竿鄉    2360      9.9
# 367  106                                             連江縣莒光鄉    1624      4.7
# 368  106                                             連江縣東引鄉    1352      3.8
# 369  106                                               東沙群島      …      2.38
# 370  106                                               南沙群島      …    0.5045
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 346    552
# 347   5108
# 348    959
# 349   1696
# 350  10467
# 351   4552
# 352   4569
# 353   4876
# 354   6330
# 355   9578
# 356   1421
# 357   4049
# 358   4931
# 359   1994
# 360    705
# 361    499
# 362   1033
# 363    794
# 364    571
# 365    725
# 366    238
# 367    346
# 368    356
# 369     …
# 370     …
# 371    NaN
# 372    NaN
# 373    NaN
# 374    NaN
# 375    NaN

# %%
dataFrame.drop([371, 372, 373, 374, 375])
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
dataFrame=dataFrame[:370]
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]
