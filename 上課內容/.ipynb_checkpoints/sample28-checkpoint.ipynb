# %%
import urllib3
import certifi

CSV_URL = "https://opendata.epa.gov.tw/api/v1/AQI?%24skip=0&%24top=1000&%24format=csv"
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
response = http.request('GET', CSV_URL)
if response.status == 200:
    print("下載成功")
    with open('空氣品質指標.csv','wb') as file:
        file.write(response.data)    
else:
    print("下載失敗")
# Out:
# 下載成功

# %%
import pandas as pd
dataFrame=pd.read_csv('空氣品質指標.csv')
dataFrame[['SiteName', 'County', 'AQI', 'PublishTime']]
# Out:
#    SiteName County  AQI       PublishTime
# 0    臺南(北門)    臺南市   23  2020-06-09 19:00
# 1    屏東(琉球)    屏東縣   21  2020-06-09 19:00
# 2    臺南(麻豆)    臺南市   22  2020-06-09 19:00
# 3    彰化(大城)    彰化縣   26  2020-06-09 19:00
# 4       富貴角    新北市   27  2020-06-09 19:00
# ..      ...    ...  ...               ...
# 76       土城    新北市   27  2020-06-09 19:00
# 77       新店    新北市   25  2020-06-09 19:00
# 78       萬里    新北市   31  2020-06-09 19:00
# 79       汐止    新北市   36  2020-06-09 19:00
# 80       基隆    基隆市   27  2020-06-09 19:00
#
# [81 rows x 4 columns]

# %%
dataFrame.reindex(columns=['SiteName', 'County', 'AQI', 'PublishTime'])
# Out:
#    SiteName County  AQI       PublishTime
# 0    臺南(北門)    臺南市   23  2020-06-09 19:00
# 1    屏東(琉球)    屏東縣   21  2020-06-09 19:00
# 2    臺南(麻豆)    臺南市   22  2020-06-09 19:00
# 3    彰化(大城)    彰化縣   26  2020-06-09 19:00
# 4       富貴角    新北市   27  2020-06-09 19:00
# ..      ...    ...  ...               ...
# 76       土城    新北市   27  2020-06-09 19:00
# 77       新店    新北市   25  2020-06-09 19:00
# 78       萬里    新北市   31  2020-06-09 19:00
# 79       汐止    新北市   36  2020-06-09 19:00
# 80       基隆    基隆市   27  2020-06-09 19:00
#
# [81 rows x 4 columns]
