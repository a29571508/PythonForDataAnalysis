# %%
import urllib3
import certifi

CSV_URL = "https://opendata.epa.gov.tw/api/v1/AQI?%24skip=0&%24top=1000&%24format=csv"
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
response = http.request('GET', CSV_URL)
if response.status == 200:
    print("下載成功")
    with open('空氣品質指標.csv','wb') as file:
        file.write(response.data)    
else:
    print("下載失敗")
# Out:
# 下載成功

# %%
import pandas as pd
dataFrame=pd.read_csv('空氣品質指標.csv')
dataFrame
# Out:
#    SiteName County  AQI  Pollutant Status  SO2    CO  CO_8hr   O3  O3_8hr  \
# 0    臺南(北門)    臺南市   23        NaN     良好  0.0  0.11     0.1   18    25.0
# 1    屏東(琉球)    屏東縣   21        NaN     良好  1.5  0.16     0.2   18    23.0
# 2    臺南(麻豆)    臺南市   22        NaN     良好  0.4  0.37     0.3  9.2    21.0
# 3    彰化(大城)    彰化縣   26        NaN     良好  2.0  0.21     0.2   17    28.0
# 4       富貴角    新北市   27        NaN     良好  0.2  0.17     0.1   31    29.0
# ..      ...    ...  ...        ...    ...  ...   ...     ...  ...     ...
# 76       土城    新北市   27        NaN     良好  2.4  0.74     0.4    8    27.0
# 77       新店    新北市   25        NaN     良好  1.9  0.38     0.3   13    24.0
# 78       萬里    新北市   31        NaN     良好  2.3  0.27     0.3   25    33.0
# 79       汐止    新北市   36        NaN     良好  1.5  0.52     0.5  9.5    20.0
# 80       基隆    基隆市   27        NaN     良好  0.7  0.35     0.4  6.6    20.0
#
#     ...    NO WindSpeed  WindDirec       PublishTime  PM2.5_AVG  PM10_AVG  \
# 0   ...   0.5       1.1      149.0  2020-06-09 19:00          4        15
# 1   ...   0.5       0.7      305.0  2020-06-09 19:00          5         8
# 2   ...  17.0       0.5      110.0  2020-06-09 19:00          4        24
# 3   ...   1.4       2.9       89.0  2020-06-09 19:00          3        18
# 4   ...   0.1       2.8       93.0  2020-06-09 19:00          6        20
# ..  ...   ...       ...        ...               ...        ...       ...
# 76  ...   7.2       1.1      153.0  2020-06-09 19:00          8        23
# 77  ...   5.4       2.1      143.0  2020-06-09 19:00          8        15
# 78  ...   1.1       1.4      353.0  2020-06-09 19:00          9        14
# 79  ...   7.6       1.2       43.0  2020-06-09 19:00         11        25
# 80  ...  10.0       0.7      285.0  2020-06-09 19:00          8        21
#
#     SO2_AVG   Longitude   Latitude  SiteId
# 0       1.0  120.124444  23.264722     310
# 1       2.0  120.377222  22.352222     204
# 2       1.0  120.245831  23.179047     203
# 3       2.0  120.273117  23.843139     202
# 4       1.0  121.536763  25.298562      84
# ..      ...         ...        ...     ...
# 76      2.0  121.451861  24.982528       5
# 77      2.0  121.537778  24.977222       4
# 78      2.0  121.689881  25.179667       3
# 79      3.0  121.642300  25.067131       2
# 80      2.0  121.760056  25.129167       1
#
# [81 rows x 24 columns]
