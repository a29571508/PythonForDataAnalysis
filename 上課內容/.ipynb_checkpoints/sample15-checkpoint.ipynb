# %%
file = open('data.txt','r',encoding='utf-8')
content = file.read()
print(type(content))
file.close()
# Out:
# <class 'str'>

# %%
import csv
file = open('健保特約醫事機構.csv','r', encoding='utf-8')
content = csv.reader(file)
contentList = list(content)
conteneList[0][1]
# Out:
# [['\ufeff醫事機構代碼',
#   '醫事機構名稱',
#   '醫事機構種類',
#   '電話',
#   '地址',
#   '分區業務組',
#   '特約類別',
#   '服務項目',
#   '診療科別',
#   '終止合約或歇業日期',
#   '固定看診時段',
#   '備註'],
#  ['5945030076',
#   '仁仁藥局',
#   '藥師自營',
#   '03-8886566',
#   '花蓮縣玉里鎮光復路１５２號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '110/09/18',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '晚上到7:00'],
#  ['5945030094',
#   '德興藥局',
#   '藥師自營',
#   '03-8889408',
#   '花蓮縣玉里鎮國武里中山路２段５８號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/20',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩販售、平常日下午一點開始、周日下午三點開始、成人口罩200份、兒童口罩20份、售完為止。'],
#  ['5945040036',
#   '黃藥局',
#   '藥師自營',
#   '03-8267211',
#   '花蓮縣新城鄉北埔村北埔路２０３號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/04',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '服務時段：早上8-12；下午2-9'],
#  ['5945050069',
#   '富一藥局',
#   '藥師自營',
#   '03-8531432',
#   '花蓮縣吉安鄉宜昌村中華路２段２０１號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/05/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午休診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩販售時間為上午8:30售完為止'],
#  ['5945050176',
#   '永和藥局',
#   '藥師自營',
#   '03-8573247',
#   '花蓮縣吉安鄉北昌村建國路１段１４５號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/04/14',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩販售時間：星期一到六早上9:00開始、賣完為止 4/13 4/14無兒童口罩'],
#  ['5945051208',
#   '祥安藥局',
#   '藥劑生自營',
#   '03-8549719',
#   '花蓮縣吉安鄉南昌村吉興路１段８９號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/01/01',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '口罩販售時間:星期一至星期六上午8:30 營業時間內皆可、售完為止'],
#  ['5945051226',
#   '仁里藥局',
#   '藥師自營',
#   '03-8512569',
#   '花蓮縣吉安鄉中正路１段１６３號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午休診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '口罩下午6:00~晚上9:30前領購、營業時間早上9點至晚上9點30、下午1~4點休息(週六日休息)'],
#  ['5945051271',
#   '小叮噹藥局',
#   '藥師自營',
#   '03-8576886',
#   '花蓮縣吉安鄉建國路１段６３號１樓',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/28',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '早上8:30~12:00、下午4:00~6:30、晚上7:00~10:00*口罩販售時間星期一至星期六11:30~12:30、18:30~19:30*'],
#  ['5945070516',
#   '平安藥局',
#   '藥師自營',
#   '03-8700765',
#   '花蓮縣光復鄉光華里忠孝路９８號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/04',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '口罩販賣服務時間：上午0900-1100、上午成人口罩100名額  、 下午1500-1800、 下午成人口罩100名額 、售完為止。'],
#  ['5945070534',
#   '菩濟藥局',
#   '藥師自營',
#   '03-8705968',
#   '花蓮縣光復鄉敦厚路６號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/12/16',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '服務時間：0740-1730、 1900-2130。口罩販賣自上午8-12、下午2-5:30。'],
#  ['5946010201',
#   '大長春藥局',
#   '藥師自營',
#   '089-322466',
#   '臺東縣臺東市中山路３５３號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '-'],
#  ['5946010229',
#   '晃成藥局',
#   '藥師自營',
#   '089-336981',
#   '臺東縣臺東市更生路４９４號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/28',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每天早上10\uf848開始領取、發完為止'],
#  ['5946010256',
#   '健康大藥局',
#   '藥師自營',
#   '089-347049',
#   '臺東縣臺東市新生路４８９號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/06/23',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '口罩於周一至周六早上八點半發號碼牌、中午12點後可領取'],
#  ['5946011459',
#   '賀順藥局',
#   '藥師自營',
#   '089-345223',
#   '臺東縣臺東市更生路５６號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/12/08',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '實名制口罩販賣時間每星期一至星期五為下午2:30開始、星期六為早上9:00。服務時間：0830-1200、 1430-1730、 1900-2100.'],
#  ['5946011477',
#   '杏林藥局',
#   '藥劑生自營',
#   '089-328674',
#   '臺東縣臺東市中正里光明路１２６號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/01',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '周1-周日早上9點口罩開始至售完止'],
#  ['5946011486',
#   '大東藥局',
#   '藥師自營',
#   '089-349747',
#   '臺東縣臺東市中山路２３８號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/12/19',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '口罩代售時間週一到週五上午8:30至12:00、下午15:00至17:30、週六上午8:30至12:00'],
#  ['5946011566',
#   '正德藥局',
#   '藥師自營',
#   '089-334181',
#   '臺東縣臺東市更生路１９９號２樓',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/23',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午休診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '營業時間上午08:30開始代售口罩；售完為止。'],
#  ['5946030025',
#   '大豐藥局',
#   '藥師自營',
#   '089-810502',
#   '臺東縣關山鎮中華路３８號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/23',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '早上0800隨到隨領'],
#  ['5946030034',
#   '宏順藥局',
#   '藥師自營',
#   '089-813536',
#   '臺東縣關山鎮中華路１６號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/12/05',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '星期一至星期六早上七點二十分發號碼牌七點三十 分開始領口罩'],
#  ['5946041028',
#   '安康藥局',
#   '藥師自營',
#   '089-383729',
#   '臺東縣卑南鄉太平里和平路１１１之６號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/08',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '停止賣口罩服務'],
#  ['5946101065',
#   '上和藥局',
#   '藥師自營',
#   '089-864171',
#   '臺東縣池上鄉忠孝路８６號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/11/17',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午休診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上休診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '沒有防疫口罩、沒有酒精販售。'],
#  ['5946010194',
#   '陳藥局',
#   '藥師自營',
#   '089-310659',
#   '臺東縣臺東市光明路１４３號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '固定週一至周六早上8點開始代售防疫口罩'],
#  ['5945011311',
#   '祥悅藥局',
#   '藥劑生自營',
#   '03-8323808',
#   '花蓮縣花蓮市和平路５４９號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/30',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上休診、星期二晚上休診、星期三晚上休診、星期四晚上休診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '服務時段：上午9-12時、下午4:30-6:30、口罩販售時間為營業時間(不發送號碼牌)。'],
#  ['5945011366',
#   '康復藥局',
#   '藥劑生自營',
#   '03-8323658',
#   '花蓮縣花蓮市中和街２０１號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/17',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '服務時間08：00-12：00、19：00-21：00、口罩販售時間上午9時30分至11時30分(不發號碼牌)。'],
#  ['5945011428',
#   '博愛藥局',
#   '藥師自營',
#   '03-8323335',
#   '花蓮縣花蓮市南京街２７６號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/12/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '服務時段：上午8:30-12、下午3-6、晚上4:30-9時、口罩販售下午2時30分(不發號碼牌)。'],
#  ['5945011526',
#   '奧爾思藥局',
#   '藥師自營',
#   '03-8325573',
#   '花蓮縣花蓮市博愛街２１５號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午休診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上看診',
#   '營業時間9-12.15-17:30.19-21:30口罩購買同營業時間.排隊售完為止.沒營業時間星期3下午星期6下午晚上星期日上午下午'],
#  ['5945021040',
#   '人和藥局',
#   '藥劑生自營',
#   '03-8762712',
#   '花蓮縣鳳林鎮中正路２００號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/10',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上休診、星期六晚上看診、星期日晚上休診',
#   '販賣口罩服務時段：早上7點半現場排隊發號碼牌、領取口罩時間為當日上午11時至晚間8時30分、賣完為止'],
#  ['5945021059',
#   '家恩藥局',
#   '藥師自營',
#   '03-8760469',
#   '花蓮縣鳳林鎮中和路２００號之１',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午休診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上休診、星期二晚上休診、星期三晚上休診、星期四晚上休診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '本藥局自4/9(四)起、停止販賣防疫口罩'],
#  ['5945010038',
#   '德生藥局',
#   '藥師自營',
#   '03-8322676',
#   '花蓮縣花蓮市中山路３２９號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/14',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '上午9時至晚上7時00分.口罩於營業時間即開始販售.售完為止.週日休息'],
#  ['5945010047',
#   '邱藥局',
#   '藥劑生自營',
#   '03-8324573',
#   '花蓮縣花蓮市忠孝街４８號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '110/07/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '口罩不販售'],
#  ['5945010056',
#   '健安藥局',
#   '藥師自營',
#   '03-8323031',
#   '花蓮縣花蓮市中山路５３７號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午休診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '例假日休、上午8時半至晚上10時、口罩販售時間同上班時間 售完為止'],
#  ['5945010118',
#   '永昇藥局',
#   '藥劑生自營',
#   '03-8225887',
#   '花蓮縣花蓮市化道路２１２之１號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '110/01/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午休診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '服務時段：上午8時-晚上9時、口罩販售時間為下午1時開始直至下午7時止。周日休息'],
#  ['5945010136',
#   '保康藥局',
#   '藥師自營',
#   '03-8579760',
#   '花蓮縣花蓮市建國路２段３４０號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/05/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '服務時段：上午8時－晚上10時；口罩販售時間下午2時起。'],
#  ['5945010154',
#   '郭藥局',
#   '藥師自營',
#   '03-8230761',
#   '花蓮縣花蓮市中美路９５號之３',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午休診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '服務時段：上午10-12、下午2:30-4:30、晚上7-8:30'],
#  ['5945010252',
#   '吉康藥局',
#   '藥師自營',
#   '03-8331208',
#   '花蓮縣花蓮市中正路３６０號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/13',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '早上8時至晚上10時、口罩販售時間上午8時至10時(不發號碼牌、現場直接給)。'],
#  ['5945010289',
#   '易生藥局',
#   '藥劑生自營',
#   '03-8322927',
#   '花蓮縣花蓮市中正路４４３號',
#   '東區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/14',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '08：00-22：00、口罩販售同營業時間。星期日08:00-12:00'],
#  ['5944040014',
#   '金福藥局',
#   '藥劑生自營',
#   '06-9984048',
#   '澎湖縣西嶼鄉池東村４３之２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/02',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '口罩：週一到週六 8：00 發放號碼牌及販售  週日 8：00 到 10：00 發放號碼牌及販售'],
#  ['5943010272',
#   '新東海藥局',
#   '藥師自營',
#   '08-7224861',
#   '屏東縣屏東市長春里民生路１１６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/25',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自5/1日~5/31日、營業日08:00~22:00為販賣口罩時間、售完為止.星期日如果是有剩餘之口罩.一樣販售至完畢為止.'],
#  ['5943010281',
#   '應安藥局',
#   '藥師自營',
#   '08-7327128',
#   '屏東縣屏東市必信里民族路３０５－７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日14:00~22:00為販賣口罩時間、售完為止'],
#  ['5943010343',
#   '名石藥局',
#   '藥師自營',
#   '08-7363184',
#   '屏東縣屏東市大連路６０－１０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/11/08',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '營業日08:30~22:00為販賣口罩時間、售完為止'],
#  ['5943010398',
#   '銘展藥局',
#   '藥師自營',
#   '08-7371713',
#   '屏東縣屏東市大連里建豐路２５４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '-'],
#  ['5943010487',
#   '正安藥局',
#   '藥師自營',
#   '08-7655845',
#   '屏東縣屏東市永光里大同路１７７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '-'],
#  ['5943010496',
#   '惠恩藥局',
#   '藥劑生自營',
#   '08-7664830',
#   '屏東縣屏東市空翔里勝利路２０２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '防疫口罩:上午9點開始、售完為止'],
#  ['5943010629',
#   '有宏藥局',
#   '藥劑生自營',
#   '08-7365564',
#   '屏東縣屏東市中正里中正路６８８巷１１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '自5/01日~5/30日、已申請停售口罩'],
#  ['5943010665',
#   '中美藥局',
#   '藥劑生自營',
#   '08-7348697',
#   '屏東縣屏東市扶風里林森路４５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/28',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自2/11日~2/29日、營業日08:30~22:00為販賣口罩時間、售完為止'],
#  ['5943010683',
#   '弘盛藥局',
#   '藥師自營',
#   '08-7367470',
#   '屏東縣屏東市海豐街２９－１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/21',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上休診、星期二晚上休診、星期三晚上休診、星期四晚上休診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '自2/11日~2/29日、營業日9:00am~12:00am、  3:00pm~6:00pm、  為販賣口罩時間、售完為止'],
#  ['5943010763',
#   '一生藥局',
#   '藥師自營',
#   '08-7665353',
#   '屏東縣屏東市民族路４９２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/03/30',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自2/11日~2/29日、營業日09:00~21:00為販賣口罩時間、售完為止'],
#  ['5943011037',
#   '正源藥局',
#   '藥師自營',
#   '08-7558891',
#   '屏東縣屏東市龍華路１８４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/13',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日08:00~22:00為販賣口罩時間、售完為止'],
#  ['5943011135',
#   '昱昇藥師藥局',
#   '藥師自營',
#   '08-7377471',
#   '屏東縣屏東市北勢里中正路３７３－１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/11/18',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '營業時間早上7:00至晚上11:00、口罩販售時間早上8:30至晚間9:30、售完為止。'],
#  ['5943011279',
#   '馥生中西藥局',
#   '藥師自營',
#   '08-7536611',
#   '屏東縣屏東市大武里大武路５４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/23',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自4/28中午起、停止販賣健保口罩服務.'],
#  ['5943012570',
#   '和信藥局',
#   '藥師自營',
#   '08-7515918',
#   '屏東縣屏東市棒球路８９號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/01',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '請勿來電詢成人上午900片下午900片星期一12:00-14:00 15:00-18:00 星期二-星期六 10:00-12:00 15:00-18:00'],
#  ['5943012605',
#   '中正藥局',
#   '藥師自營',
#   '08-7339012',
#   '屏東縣屏東市中正路１９１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/22',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '口罩販賣時間--早上8:30~12:00 下午3:00~6:00晚上不販賣口罩. 星期日固定公休'],
#  ['5943012614',
#   '杏林藥局',
#   '藥師自營',
#   '08-7530233',
#   '屏東縣屏東市復興路１３８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '4/1日~5/31日營業日週一至週五09:00~12:00 15:00~17:30 19:00~21:30週六08:30~12:00 為販賣口罩時間、售完為止'],
#  ['5943012687',
#   '禾康藥局',
#   '藥劑生自營',
#   '08-7375818',
#   '屏東縣屏東市中正路４６０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/01',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '-'],
#  ['5942171105',
#   '中心藥局',
#   '藥劑生自營',
#   '07-6921058',
#   '高雄市茄萣區仁愛路三段２１８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/22',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '營業日7:30~10:00為販賣口罩時間、售完為止'],
#  ['5942190048',
#   '南安藥局',
#   '藥劑生自營',
#   '07-6191802',
#   '高雄市彌陀區漯底里樂安路５３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/28',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日8:00~22:00為販賣口罩時間、售完為止'],
#  ['5942240025',
#   '蔡藥局',
#   '藥師自營',
#   '07-6671131',
#   '高雄市內門區內門里內門路６４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/29',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自2/11日~2/29日、營業日8:00~10:00為販賣口罩時間.售完為止'],
#  ['5942240043',
#   '光輝藥局',
#   '藥劑生自營',
#   '07-6671106',
#   '高雄市內門區鄉觀亭里南屏路２３０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/02',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自3/01日~3/31日、營業日8:30起為販賣口罩時間、售完為止'],
#  ['5943010049',
#   '統和藥局',
#   '藥師自營',
#   '08-7379898',
#   '屏東縣屏東市德豐街６３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日09:00~22:00為販賣口罩時間、售完為止'],
#  ['5943010076',
#   '大茂藥局',
#   '藥師自營',
#   '08-7323293',
#   '屏東縣屏東市逢甲路８５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/04/04',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日08:20~22:00為販賣口罩時間、售完為止'],
#  ['5943010156',
#   '新東洋藥局',
#   '藥師自營',
#   '08-7323388',
#   '屏東縣屏東市民生路２３８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '營業日上午9:30至 晚上21:30為販賣口罩時間、售完為止'],
#  ['5943010192',
#   '立眾藥局',
#   '藥師自營',
#   '08-7665443',
#   '屏東縣屏東市勝利路１９０－４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日13:00~15:00為販賣口罩時間、售完為止'],
#  ['5942200030',
#   '順成藥局',
#   '藥師自營',
#   '07-6172407',
#   '高雄市梓官區梓官路城隍巷３１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/23',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩販賣時間為早上9:00至售完為止。'],
#  ['5942201171',
#   '郭順忠藥局',
#   '藥師自營',
#   '07-6194418',
#   '高雄市梓官區大舍南路２６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/04/10',
#   '星期一上午看診、星期二上午休診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上休診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '*週六 週日 請先電話聯繫;自3/1日~3/31日、營業日10:00起為販賣口罩時間、售完為止'],
#  ['5942220023',
#   '維康藥局',
#   '藥師自營',
#   '07-6752585',
#   '高雄市甲仙區西安里中正路２２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/01/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日07:00起為販賣口罩時間、售完為止'],
#  ['5942220032',
#   '文殊堂藥局',
#   '藥師自營',
#   '07-6752176',
#   '高雄市甲仙區西安里文化路２２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/02',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日07:30起為販賣口罩時間、售完為止。'],
#  ['5942220078',
#   '宏仁藥局',
#   '藥師自營',
#   '07-6751255',
#   '高雄市甲仙區東安里和安街４８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/02',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '-'],
#  ['5943170059',
#   '吉利藥局',
#   '藥師自營',
#   '08-8681290',
#   '屏東縣新園鄉仙吉村仙吉路１３７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '販賣口罩時間：8點、售完為止。'],
#  ['5943170077',
#   '健安藥局',
#   '藥師自營',
#   '08-8322649',
#   '屏東縣新園鄉中洲村南興路１７０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自4/11~4/30日、販賣口罩時間至8:00起、售完為止。'],
#  ['5943170095',
#   '長安中西藥局',
#   '藥劑生自營',
#   '08-8336986',
#   '屏東縣新園鄉中洲村南興路１９４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/19',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11~2/29日、販賣口罩時間9:00起、售完為止。'],
#  ['5943171163',
#   '郁達藥局',
#   '藥師自營',
#   '08-8681258',
#   '屏東縣新園鄉仙吉村仙吉路二十七之二號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '販賣口罩時間上午8點起售完為止。'],
#  ['5943190033',
#   '陽昇藥局',
#   '藥師自營',
#   '08-8751347',
#   '屏東縣林邊鄉林邊村忠孝路３１－２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '藥局販售口罩時間、依藥局門口公告時間為主(售完為止)'],
#  ['5943190042',
#   '永清堂藥局',
#   '藥劑生自營',
#   '08-8755138',
#   '屏東縣林邊鄉永樂村榮農路５巷７－３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/11/06',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '每日早上08:00開始販售口罩、售完為止'],
#  ['5943190088',
#   '壽泰健康藥局',
#   '藥劑生自營',
#   '08-8752366',
#   '屏東縣林邊鄉仁和村中山路１９１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/20',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日實名制口罩發售時間每日7：40.售完為止'],
#  ['5943191101',
#   '和成健康藥局',
#   '藥師自營',
#   '08-8752028',
#   '屏東縣林邊鄉中林路一二三號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/16',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/19日起、營業日7:00開始為販賣口罩時間、售完為止'],
#  ['5943200016',
#   '萬隆發藥局',
#   '藥劑生自營',
#   '08-8642176',
#   '屏東縣南州鄉仁里村三民路３９號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '營業日07:30-10:00為販賣口罩時間'],
#  ['5943200052',
#   '源明藥局',
#   '藥劑生自營',
#   '08-8642276',
#   '屏東縣南州鄉三民路１４８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/07/18',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自4/3起早上9.00為口罩販售時間.售完為止、週日休'],
#  ['5943210076',
#   '德馨藥局',
#   '藥劑生自營',
#   '08-8661492',
#   '屏東縣佳冬鄉石光村中山路１８５之３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/08/04',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩購買時間9點30至11點30中午休息14點至21點   星期日下午休息'],
#  ['5943231048',
#   '車城藥局',
#   '藥師自營',
#   '08-8825329',
#   '屏東縣車城鄉福興村中山路４２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/30',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上休診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '自2/11日~2/29日、營業日14:00起為販賣口罩時間、售完為止、'],
#  ['5944010025',
#   '大智藥局',
#   '藥師自營',
#   '06-9262151',
#   '澎湖縣馬公市陽明里大智街２６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午休診、星期二下午看診、星期三下午休診、星期四下午看診、星期五下午休診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '口罩販售自下午3點起、現場排隊.售完為止.上午8點至12點 下午2點半至6點 晚上7點至9點'],
#  ['5944010043',
#   '新見安藥局',
#   '藥師自營',
#   '06-9277346',
#   '澎湖縣馬公市光明里光復路９５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '營業日7點半拿號碼牌、13:00起為販賣口罩時間、售完為止、'],
#  ['5944010061',
#   '敏松藥局',
#   '藥劑生自營',
#   '06-9273241',
#   '澎湖縣馬公市民生路２５－９號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/17',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '週一到週六8:10-21：30為販賣口罩時間、星期日不販售'],
#  ['5944010070',
#   '合珍藥局',
#   '藥劑生自營',
#   '06-9953082',
#   '澎湖縣馬公市鎖港里３８７－１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '平日中午12:00-14:00休息、週六日中午休息時間11:30-14:30'],
#  ['5944010089',
#   '宏安藥局',
#   '藥師自營',
#   '06-9273048',
#   '澎湖縣馬公市中華路５４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/17',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '配合口罩實名制販售時間為08:00開始發放號碼牌、售完為止。'],
#  ['5943050105',
#   '萬丹藥局',
#   '藥師自營',
#   '08-7762889',
#   '屏東縣萬丹鄉萬安村和平西路５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/25',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自03/01日~03/31日、營業日8:30起為販賣口罩時間(賣完為止)藥局營業時間08:00~~21:30'],
#  ['5943050150',
#   '成大藥局',
#   '藥師自營',
#   '08-7771643',
#   '屏東縣萬丹鄉萬全村萬榮街８３號１．２樓',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/18',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '藥局販賣口罩時間、下午3點半至晚上6點止。 星期六早上11點開始販售。'],
#  ['5943051175',
#   '黃藥師藥局',
#   '藥師自營',
#   '08-7075529',
#   '屏東縣萬丹鄉社中村社皮路三段４２８．４３０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/05',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每週1至周6早上7點領號碼牌.'],
#  ['5943060030',
#   '睦昌藥局',
#   '藥師自營',
#   '08-7622433',
#   '屏東縣長治鄉崑崙路１８８之１５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/25',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '上午9點至晚上9點為口罩販賣時間.售完為止'],
#  ['5943060049',
#   '忠安中西藥局',
#   '藥師自營',
#   '08-7621326',
#   '屏東縣長治鄉中山路１０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '營業日07:30為販賣口罩時間.售完為止'],
#  ['5943060067',
#   '長興藥師藥局',
#   '藥師自營',
#   '08-7382328',
#   '屏東縣長治鄉長興路３０６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '營業日08:40開始販售.週日公休'],
#  ['5943070027',
#   '泰安藥局',
#   '藥師自營',
#   '08-7221543',
#   '屏東縣麟洛鄉麟頂村民生路２６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '7:30--21:00  7:30開始     星期ㄖ 休假'],
#  ['5943090029',
#   '亞洲藥局',
#   '藥師自營',
#   '08-7752938',
#   '屏東縣里港鄉永春路８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/06',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩販售時間為下午3:00至售完(週日口罩販售與否會於星期六現場公告)'],
#  ['5943100011',
#   '宏大藥局',
#   '藥師自營',
#   '08-7935513',
#   '屏東縣鹽埔鄉新二村彭厝路３８－５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/14',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '營業日上午9點起販賣口罩、售完為止。(請自備零錢、感謝)'],
#  ['5943110035',
#   '永效藥局',
#   '藥師自營',
#   '08-7960295',
#   '屏東縣高樹鄉司馬村長美路８３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '販賣口罩時間7點10分到12點、售完為止。營業時間7點-19點.'],
#  ['5943110044',
#   '宏順藥局',
#   '藥劑生自營',
#   '08-7962136',
#   '屏東縣高樹鄉長榮村南昌路２－２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/04/13',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '營業日09:00~11:00為販賣口罩時間、售完為止。'],
#  ['5943110062',
#   '永昌藥局',
#   '藥師自營',
#   '08-7956087',
#   '屏東縣高樹鄉產業路１６３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/23',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '賣口罩時間 上午7:20-12:00、下午2:00至售完為止'],
#  ['5943120022',
#   '何藥局',
#   '藥劑生自營',
#   '08-7836888',
#   '屏東縣萬巒鄉佳佐村民生路１２９號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/04/23',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自4/7日起、週一至週六07:30至22:00為販賣口罩時間、週日照常販售、售完為止。'],
#  ['5943130055',
#   '和安藥局',
#   '藥師自營',
#   '08-7792647',
#   '屏東縣內埔鄉東勢村嘉應路２７－１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自2/11日~2/29日、營業日10:00至21:00為販賣口罩時間、售完為止。'],
#  ['5943130064',
#   '長生藥局',
#   '藥師自營',
#   '08-7792121',
#   '屏東縣內埔鄉仁和路７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/13',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '4/24開始;營業時間 早上9點 開始販售  週日公休!!'],
#  ['5943130082',
#   '健林藥局',
#   '藥師自營',
#   '08-7790635',
#   '屏東縣內埔鄉中興路１５７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自2/11日~2/29日、營業日08:00至21:30為販賣口罩時間、售完為止。(週日公休)'],
#  ['5943151027',
#   '安泰藥局新埤店',
#   '藥師自營',
#   '08-7973793',
#   '屏東縣新埤鄉新華路１６３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/29',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '自2/14日起、販賣口罩8:30開始、售完為止'],
#  ['5943160017',
#   '仁慧藥局',
#   '藥劑生自營',
#   '08-8780472',
#   '屏東縣枋寮鄉中山路１８１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '-'],
#  ['5943160026',
#   '吉村藥局',
#   '藥師自營',
#   '08-8781593',
#   '屏東縣枋寮鄉安樂村中山路８５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/08',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '販賣時間上午8點發放號碼牌依序購買、售完為止。每周(日)停售口罩'],
#  ['5943160035',
#   '隆山藥局',
#   '藥師自營',
#   '08-8785700',
#   '屏東縣枋寮鄉安樂村中山路１１５－２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/09',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11~2/29日、販賣口罩時間8:00起、售完為止。'],
#  ['5943012801',
#   '瑞光藥局',
#   '藥師自營',
#   '08-7380002',
#   '屏東縣屏東市瑞光路二段２５０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/10',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上休診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '自2/11日~2/29日、營業日14:30~16:30為販賣口罩時間、售完為止'],
#  ['5943020036',
#   '長庚中西藥局',
#   '藥師自營',
#   '08-7896626',
#   '屏東縣潮州鎮三共里朝昇路２３５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/25',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '口罩10:00開始代售 星期天公休'],
#  ['5943020063',
#   '大安藥局',
#   '藥師自營',
#   '08-7884500',
#   '屏東縣潮州鎮永春里光春路７１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '口罩販賣0800-0900&1800-1900'],
#  ['5943020125',
#   '信安西藥局',
#   '藥劑生自營',
#   '08-7882176',
#   '屏東縣潮州鎮同榮里中山路７０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/09',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '藥局販售口罩時間為早上10 : 00至中午12 : 00以及 下午5 : 00至晚上 9 : 20(售完為止)'],
#  ['5943020161',
#   '惠安藥局',
#   '藥劑生自營',
#   '08-7882368',
#   '屏東縣潮州鎮新榮里新生路３１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '星期一~六:8:00~11:30/14:30~21:30 星期日16:30~21:00'],
#  ['5943020170',
#   '一心藥局',
#   '藥劑生自營',
#   '08-7889789',
#   '屏東縣潮州鎮育英路１７－１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '藥局販售口罩時間、依藥局門口公告時間為主(售完為止)'],
#  ['5943020241',
#   '健銘藥局',
#   '藥師自營',
#   '08-7897631',
#   '屏東縣潮州鎮新生里新生路１４７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/10',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '星期一到星期六早上8點45開始 售完為止(剩餘數量藥局當下為準)'],
#  ['5943020367',
#   '安欣藥師藥局',
#   '藥師自營',
#   '08-7805759',
#   '屏東縣潮州鎮延平路一六八號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/16',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自2/11日~2/29日、營業日13:00~15:00為販賣口罩時間、售完為止'],
#  ['5943030023',
#   '益福藥局',
#   '藥師自營',
#   '08-8338248',
#   '屏東縣東港鎮朝安里新生三路２１２－４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/01/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '-'],
#  ['5943030032',
#   '振康藥師藥局',
#   '藥師自營',
#   '08-8352520',
#   '屏東縣東港鎮光復路二段１０１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/12/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩販賣時間:星期1~星期6早上8點開始排隊販賣、賣完為止'],
#  ['5943030103',
#   '保生藥局',
#   '藥師自營',
#   '08-8322818',
#   '屏東縣東港鎮中山路５６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/20',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '上午8:30至晚上9:00販賣口罩、上午8:30開始發號碼牌、售完為止'],
#  ['5943030112',
#   '怡仁藥局',
#   '藥師自營',
#   '08-8322159',
#   '屏東縣東港鎮頂中里中正路１０７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '上午8:30開始賣口罩、有事時改下午2:30、以現場公告為主、售完為止'],
#  ['5943031244',
#   '福興藥局',
#   '藥師自營',
#   '08-8336012',
#   '屏東縣東港鎮興漁里順漁路１１１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/04/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午休診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '-'],
#  ['5943040047',
#   '聖鑫藥局',
#   '藥師自營',
#   '08-8891132',
#   '屏東縣恆春鎮中正路７３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/01/16',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日13:00起為販賣口罩時間(賣完為止)'],
#  ['5943040074',
#   '育誠藥局',
#   '藥師自營',
#   '08-8892782',
#   '屏東縣恆春鎮西門路１０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/16',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上休診、星期二晚上休診、星期三晚上休診、星期四晚上休診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '自5/1-5/31、星期一至六上午7:30發號碼牌現場購買.星期日休息不販賣口罩'],
#  ['5943050025',
#   '博林藥局',
#   '藥師自營',
#   '08-7072876',
#   '屏東縣萬丹鄉社皮村大昌路４５８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/03/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '賣口罩早上8:00起售完為止'],
#  ['5943050034',
#   '全安堂藥局',
#   '藥劑生自營',
#   '08-7772571',
#   '屏東縣萬丹鄉香社村中興路一段１５６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '-'],
#  ['5942020023',
#   '醫聯藥局',
#   '藥師自營',
#   '07-6259873',
#   '高雄市岡山區前峰里公園西路３段１２５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午休診、星期三下午看診、星期四下午看診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '營業日早上8:00開始排隊配售口罩、售完為止'],
#  ['5942020050',
#   '惠光西藥局',
#   '藥師自營',
#   '07-6212163',
#   '高雄市岡山區維仁路１４７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/28',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '販賣時間為上午9:00售完為止'],
#  ['5942020078',
#   '協安大藥局',
#   '藥師自營',
#   '07-6252256',
#   '高雄市岡山區介壽西路１０號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '營業日早上8點45分為販賣口罩時間'],
#  ['5902111796',
#   '力安藥師藥局',
#   '藥師自營',
#   '07-7918167',
#   '高雄市小港區桂陽路316號１樓',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/18',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '週一~六早上7點30分發200張號碼牌.週日休息'],
#  ['5942010081',
#   '杏門藥局',
#   '藥師自營',
#   '07-7635781',
#   '高雄市鳳山區老爺里海洋二路１７８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/08',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '周一-周六 上午8:45分發碼牌、12:00後領口罩、周日停發口罩'],
#  ['5942010125',
#   '中央藥局',
#   '藥師自營',
#   '07-8217320',
#   '高雄市鳳山區五甲三路７１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/11/21',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '早上7點55分發大人180份.小孩20份口罩號碼牌、憑號碼牌8點後立即購買、賣完為止。星期日無販賣兒童口罩。'],
#  ['5942010214',
#   '謝藥局',
#   '藥師自營',
#   '07-7226685',
#   '高雄市鳳山區南江街１２６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '110/09/17',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '自2/11日~2/29日、營業日07:10~21:20為販賣口罩時間、售完為止'],
#  ['5942010269',
#   '大華藥局',
#   '藥師自營',
#   '07-7774881',
#   '高雄市鳳山區青年路二段４６６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午休診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上休診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '藥局販售口罩時間、依藥局門口公告時間為主'],
#  ['5942010312',
#   '星輝藥局',
#   '藥師自營',
#   '07-7461830',
#   '高雄市鳳山區瑞竹路２０之５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/02',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '-'],
#  ['5942010321',
#   '南億藥局',
#   '藥師自營',
#   '07-7105010',
#   '高雄市鳳山區光復路７４號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '一~六早上10-12點販賣口罩、上午若沒賣完、下午14-16續賣。'],
#  ['5942010349',
#   '長英藥局',
#   '藥師自營',
#   '07-7805002',
#   '高雄市鳳山區八德路二段２６７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '營業日16:00~18:00為販賣口罩時間、售完為止。'],
#  ['5942010358',
#   '護民藥局',
#   '藥師自營',
#   '07-7462525',
#   '高雄市鳳山區光遠路２０５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '下午3點現場發放口罩'],
#  ['5942010447',
#   '健生大藥局',
#   '藥師自營',
#   '07-7131028',
#   '高雄市鳳山區五甲二路１８２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/25',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自2/11日~2/29日、營業日09:00發口罩號碼牌、售完為止'],
#  ['5942010563',
#   '一心堂藥局',
#   '藥劑生自營',
#   '07-8213971',
#   '高雄市鳳山區五甲二路５２３號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每天下午2:50發放號碼牌、 3:00現場直接叫號販售口罩、 下午5:00截止'],
#  ['5942010643',
#   '王藥局',
#   '藥劑生自營',
#   '07-7716581',
#   '高雄市鳳山區一甲里南江街１２９號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/02/02',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '營業時間上午7:40- 21:30(下午13:00-15:00休息)周日下午休息'],
#  ['5942010787',
#   '強生藥局',
#   '藥劑生自營',
#   '07-7468179',
#   '高雄市鳳山區中山西路１７５號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/14',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '原則上一個月有兩天不定期休假'],
#  ['5942010812',
#   '一仁藥局',
#   '藥劑生自營',
#   '07-7425004',
#   '高雄市鳳山區自由路２００號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/23',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '週一至週日:15:00~20:00(周日非固定營業)'],
#  ['5942010867',
#   '鳳林藥局',
#   '藥師自營',
#   '07-7830767',
#   '高雄市鳳山區鳳林路１６６號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/04/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '周一至周六09:00依號碼牌開始販售成人9入口罩兒童10入口罩'],
#  ['5902110066',
#   '文祺藥局',
#   '藥師自營',
#   '07-8014066',
#   '高雄市小港區正苓里平治街１１２號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/01/28',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '自2/11日~2/29日、6:00發號碼牌、14:00為販賣口罩時間.售完為止'],
#  ['5902110093',
#   '鳳明中西大藥局',
#   '藥師自營',
#   '07-8011846',
#   '高雄市小港區二苓路２４７號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/04/17',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '下午2點賣大人兒童口罩 星期日全國停售一天.'],
#  ['5902110244',
#   '億大藥局',
#   '藥師自營',
#   '07-8014958',
#   '高雄市小港區三苓里永義街１７１號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/08',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '藥局販售口罩時間、依藥局門口公告時間為主(售完為止)'],
#  ['5902092410',
#   '旺盛藥局',
#   '藥劑生自營',
#   '07-7512899',
#   '高雄市前鎮區永豐路１０８號',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/01/06',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '早上10點開賣口罩、售完為止'],
#  ['5902092492',
#   '元生藥局',
#   '藥劑生自營',
#   '07-8156356',
#   '高雄市前鎮區鎮興路２２６號１樓',
#   '高屏業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/15',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每日8點開始賣.售完為止藥局販售口罩時間、依藥局門口公告時間為主(售完為止)'],
#  ['5902092554',
#   '協和藥局',
# ...
#   '固定週一至週日早上9:00開始販售口罩.售完為止'],
#  ['5917030860',
#   '振聲藥局',
#   '藥師自營',
#   '04-24721100',
#   '臺中市西區公正里向上路１段４４７號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '週一至週六早上9:00開始販售口罩、售完為止'],
#  ['5917081214',
#   '吉成藥局',
#   '藥師自營',
#   '04-22435556',
#   '臺中市北屯區松茂里松竹路二段１３９號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩業務結束'],
#  ['5917082300',
#   '蔡宗耀中西藥局',
#   '藥師自營',
#   '04-22341880',
#   '臺中市北屯區平德里河北路２段６１號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/07',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '早上9點30分至下午12點30分、下午3點至8點發口罩、有發號碼牌。'],
#  ['5917082364',
#   '慈慧藥師藥局',
#   '藥師自營',
#   '04-22389846',
#   '臺中市北屯區平田里昌平路１段１７８號１Ｆ',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '星期一到星期六早上9點開始販賣口罩、全天後供應售完為止星期日機動'],
#  ['5917032462',
#   '名亨藥局',
#   '藥師自營',
#   '04-22201089',
#   '臺中市西區五權路２９號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/30',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '每日上午8:30至12、下午3至7:00販售.周 日  休 息. 周 六    下 午 休 息 .'],
#  ['5917032471',
#   '銘津藥局',
#   '藥師自營',
#   '04-23021314',
#   '臺中市西區民生路３９０號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/30',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '每日上午10:00至13:00、下午3:00至21:00 現場排隊、星期日下午休息'],
#  ['5917032515',
#   '友富大藥局',
#   '藥劑生自營',
#   '04-23199668',
#   '臺中市西區向上路一段５００號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '口罩販售時間早上10:00-12:00、下午2:00-6:00止、 星期日公休'],
#  ['5917082604',
#   '科學藥局',
#   '藥師自營',
#   '04-22936688',
#   '臺中市北屯區中清路２段３１６號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/01/12',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '早上9:00開始販賣口罩.星期日停售'],
#  ['5917082659',
#   '信誼藥局',
#   '藥師自營',
#   '04-22478695',
#   '臺中市北屯區瀋陽路二段３１號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/16',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '週一~週五下午15:00-18:00、週六上午9:00-12:00販售口罩、周日公休。'],
#  ['5936010057',
#   '慈安藥局',
#   '藥劑生自營',
#   '04-25236680',
#   '臺中市豐原區西湳里豐北街４０３號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '防疫口罩上午7點45分發完號碼牌後即販售12點前須購買完畢、另平常前往領藥優先領取'],
#  ['5917070462',
#   '長映藥局',
#   '藥師自營',
#   '04-22510951',
#   '臺中市南屯區黎明路二段４３２號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/13',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '固定周一到周六、早上9:00；禮拜天11:00點開始販賣防疫口罩。'],
#  ['5917070659',
#   '德安藥局',
#   '藥師自營',
#   '04-23894920',
#   '臺中市南屯區文山里忠勇路１１５－６號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/22',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩每天早上九點半後開賣。'],
#  ['5917071727',
#   '大愛藥局',
#   '藥師自營',
#   '04-24733646',
#   '臺中市南屯區向心南路９６２．９６４號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/04',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每日上午08:30直接發放200份、4/18日之後每個星期一停止販售口罩、公休1天!如還有口罩庫存繼續發放'],
#  ['5917020060',
#   '來安藥局',
#   '藥師自營',
#   '04-22116977',
#   '臺中市東區十甲東路４８８號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/18',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '發口罩時間早上9點'],
#  ['5917020097',
#   '泰興藥局',
#   '藥師自營',
#   '04-22112537',
#   '臺中市東區東南里十甲路１１－１號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/12/19',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '每天AM07:30開賣、不發號碼牌'],
#  ['5917071736',
#   '承智藥局',
#   '藥師自營',
#   '04-23280302',
#   '臺中市南屯區溝墘里大墩路８１０號之１',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/09',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '早上9:00--14:00;下午15:30--21:00、星期日休、國定假日休'],
#  ['5917071781',
#   '吉運藥局',
#   '藥劑生自營',
#   '04-23834755',
#   '臺中市南屯區南屯里黎明路１段１１３５號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/04/05',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '固定周一到周六、早上8:00賣防疫口罩。'],
#  ['5917071996',
#   '乾生大藥局',
#   '藥劑生自營',
#   '04-23281277',
#   '臺中市南屯區大業路９５號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/16',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '固定周一到周六、早上8:30開始販賣。'],
#  ['5917020104',
#   '七星中西藥局',
#   '藥師自營',
#   '04-22123014',
#   '臺中市東區東信里十甲東路４０６巷１號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '110/06/20',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '口罩AM9:00開賣'],
#  ['5917020122',
#   '周藥師藥局',
#   '藥師自營',
#   '04-23606800',
#   '臺中市東區合作里力行路５５號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '無'],
#  ['5917020186',
#   '建中藥局',
#   '藥劑生自營',
#   '04-22813589',
#   '臺中市東區大智路１９０號１Ｆ',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午休診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '每日上午9點現場排隊購買、賣完為止'],
#  ['5917020202',
#   '一心藥局',
#   '藥師自營',
#   '04-23609012',
#   '臺中市東區合作里力行路４２-１號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '代售口罩星期一至星期六。'],
#  ['5917020211',
#   '何藥局',
#   '藥師自營',
#   '04-23604631',
#   '臺中市東區東勢里精武路１８０號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '防疫口罩販售分兩批 第一批早上8:30販售、第二批晚上6:30販售。'],
#  ['5917020337',
#   '福生藥局',
#   '藥劑生自營',
#   '04-22119106',
#   '臺中市東區福仁街138號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '代售口罩時間周一至周六、早上8:00開始販售.售完為止.星期日8:00-9:30分'],
#  ['5917020346',
#   '許回生中西大藥局',
#   '藥師自營',
#   '04-22806293',
#   '臺中市東區建成路６６６號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '固定周一至周六下午一點現常排隊購買.結束為止....'],
#  ['5917020373',
#   '明大藥局',
#   '藥劑生自營',
#   '04-22152388',
#   '臺中市東區振興路２８８號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/01/11',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '每日早上9點開始販售、販售至晚上7點止(星期日不販售)。'],
#  ['5917080119',
#   '李藥局',
#   '藥師自營',
#   '04-22390950',
#   '臺中市北屯區和順路３９８號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '周一至周日、早上8點半開始販售、售完為止'],
#  ['5917080137',
#   '日盛藥局',
#   '藥師自營',
#   '04-24360810',
#   '臺中市北屯區東山路一段１４２-１１號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每天(不含星期日)早上09:00開始發售口罩、售完為止。'],
#  ['5917080262',
#   '寶麒藥局',
#   '藥劑生自營',
#   '04-22433918',
#   '臺中市北屯區旅順路２段１５０號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/08/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '固定周一~周日每天下午1:00開始販售口罩、現場排隊不發號碼牌'],
#  ['5917080306',
#   '資生藥局',
#   '藥師自營',
#   '04-22926553',
#   '臺中市北屯區水湳里大連路一段５５號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/26',
#   '星期一上午休診、星期二上午休診、星期三上午休診、星期四上午休診、星期五上午休診、星期六上午休診、星期日上午休診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上休診、星期二晚上休診、星期三晚上休診、星期四晚上休診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '-'],
#  ['5917080342',
#   '弘光藥局',
#   '藥劑生自營',
#   '04-22342999',
#   '臺中市北屯區太原路三段４５８號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '111/11/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '早上8:30開始販賣防疫口罩(全年無休)'],
#  ['5917080379',
#   '大元藥局',
#   '藥劑生自營',
#   '04-22357722',
#   '臺中市北屯區北屯里昌平路一段２３號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/26',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '周一~周六每天18:00至21:00販售口罩、 口罩剩很多已成為政府防疫口罩戰備儲存地、星期日公休晚上不確定販售'],
#  ['5917080388',
#   '濟生藥局',
#   '藥劑生自營',
#   '04-22472327',
#   '臺中市北屯區松安里昌平路二段２之３１號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '周一~周日每天上午9:00開始發號碼牌並依序販售口罩、售完為止'],
#  ['5917080413',
#   '中央藥局',
#   '藥劑生自營',
#   '04-22340208',
#   '臺中市北屯區北屯里進化北路２７號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/28',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上休診、星期日晚上休診',
#   '周一~周日每天下午2:00開始發號碼牌並依序販售口罩、售完為止'],
#  ['5917030066',
#   '立安藥局',
#   '藥師自營',
#   '04-23719125',
#   '臺中市西區土庫里忠明南路３４８號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/29',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '每天09:00開始依排隊先後序開始發放號碼牌並配售口罩、售完為止。'],
#  ['5917030100',
#   '裕源藥局',
#   '藥師自營',
#   '04-23763133',
#   '臺中市西區公館里南屯路一段６６－７號一樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/12/19',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '固定周一至周六09:00依序販售口罩、周日休息'],
#  ['5917030128',
#   '太信藥局',
#   '藥劑生自營',
#   '04-23718318',
#   '臺中市西區三民路一段９５－１號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/11/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '請每天09-19點→健保卡&口罩'],
#  ['5917080431',
#   '道安藥局',
#   '藥劑生自營',
#   '04-22450357',
#   '臺中市北屯區昌平路二段２\uf848４５號１Ｆ',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/05',
#   '星期一上午休診、星期二上午休診、星期三上午休診、星期四上午休診、星期五上午休診、星期六上午休診、星期日上午休診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午看診、星期六下午休診、星期日下午休診、星期一晚上休診、星期二晚上休診、星期三晚上休診、星期四晚上休診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '-'],
#  ['5917080548',
#   '志誠藥局',
#   '藥師自營',
#   '04-24225682',
#   '臺中市北屯區仁美里豊樂路３２－９號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/12/19',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '周一~周六 每天早上8:30 開始販賣 防疫口罩 星期日休息'],
#  ['5917062406',
#   '健康藥局',
#   '藥師自營',
#   '04-23190305',
#   '臺中市西屯區何南里大墩１９街２６號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/09/24',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '星期一至六每天早上10:00開始領口罩(視狀況發號碼牌)、星期日休息'],
#  ['5917062559',
#   '德康藥局',
#   '藥師自營',
#   '04-23583373',
#   '臺中市西屯區福和里中工三路１５６號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/07/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每天早上10:00開始發號碼牌當場領口罩'],
#  ['5917062586',
#   '篤行藥局',
#   '藥師自營',
#   '04-23165727',
#   '臺中市西屯區何厝里西屯路二段４５之１號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/11/27',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '視人潮情況決定要不要發號碼牌、原則早上1030開始發放口罩'],
#  ['5917062620',
#   '東亞藥師藥局',
#   '藥師自營',
#   '04-27022702',
#   '臺中市西屯區河南路２段３５０號１樓',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/03/05',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每日上午十點發放口罩.售完為止'],
#  ['5917070042',
#   '財德中西藥局',
#   '藥師自營',
#   '04-23898018',
#   '臺中市南屯區南屯路二段６１８號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上休診',
#   '-'],
#  ['5917070060',
#   '仁人藥局',
#   '藥師自營',
#   '04-23890451',
#   '臺中市南屯區南屯里黎明路一段１０８５號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/06/28',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '周一到周日、8:00~22:30販售口罩、售完為止。'],
#  ['5917070088',
#   '萬安藥局',
#   '藥師自營',
#   '04-24791818',
#   '臺中市南屯區中和里黎明路一段３８號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/01/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '每日上午10點到12點預約掛號方式發放口罩(周日不發口罩)'],
#  ['5917070186',
#   '濟安堂藥局',
#   '藥師自營',
#   '04-23899603',
#   '臺中市南屯區南屯路二段７８８號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '112/05/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   '現場排隊.不發號碼牌'],
#  ['5917010046',
#   '大協藥局',
#   '藥師自營',
#   '04-22250745',
#   '臺中市中區中山路１２４號',
#   '中區業務組',
#   '藥局',
#   '-',
#   '-',
#   '109/10/31',
#   '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午休診、星期一下午休診、星期二下午休診、星期三下午休診、星期四下午休診、星期五下午休診、星期六下午休診、星期日下午休診、星期一晚上休診、星期二晚上休診、星期三晚上休診、星期四晚上休診、星期五晚上休診、星期六晚上休診、星期日晚上休診',
#   '口罩領買時間：周一至周六09:00~12:00、周日依法停賣'],
#  ...]
