# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt
data = [-1, -4.3, 15, 21, 31]
plt.figure(num='我的第一個圖表',figsize=(8, 5))
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import matplotlib.pyplot as plt
plt.figure(num=5,figsize=(8, 5))
x = [1, 2, 3, 4, 5]
y1 = [1, 2, 5, 6, 7]
y2 = [4, 5, 6, 12, 24]
plt.plot(x, y1, x, y2)
# Out:
# <img src="data:image/png;base64,..." width="800">
# [<matplotlib.lines.Line2D at 0x7ffac9c49090>,
#  <matplotlib.lines.Line2D at 0x7ffac9c49310>]

# %%
import matplotlib.pyplot as plt
plt.figure(num=6)
plt.plot([1, 2, 3, 4, 5])
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y1 = [1,2,5,6,7]
y2 = [4,5,6,7,8]
plt.figure(num = 7)
plt.plot(x, y1, 'r-o', x, y2, 'g--')
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
plt.figure('第一個圖表')
plt.title("My Firet plot")
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# Out:
# <img src="data:image/png;base64,..." width="640">
