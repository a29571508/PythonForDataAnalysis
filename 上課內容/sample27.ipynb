# %%
import pandas as pd
# !cat ex1.csv
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
dataFrame = pd.read_csv('ex1.csv')
dataFrame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
import urllib3
import certifi
import csv

CSV_URL = "https://opendata.epa.gov.tw/api/v1/AQI?%24skip=0&%24top=1000&%24format=csv"
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
r = http.request('GET', CSV_URL)
if r.status == 200:    
    with open('空氣品質指標.csv','wb') as file:
        file.write(r.data)
        file.close()

# %%
apiDataFrame = pd.read_csv('空氣品質指標.csv')
apiDataFrame
# Out:
#    SiteName County  AQI  Pollutant Status  SO2    CO  CO_8hr   O3  O3_8hr  \
# 0    臺南(北門)    臺南市   18        NaN     良好  0.3  0.08     0.1   18    19.0
# 1    屏東(琉球)    屏東縣   23        NaN     良好  0.0  0.09     0.1   22    23.0
# 2    新北(樹林)    新北市   28        NaN     良好  1.4  0.41     0.3  9.9    29.0
# 3    彰化(大城)    彰化縣   21        NaN     良好  3.0  0.26     0.3   13    23.0
# 4    臺南(麻豆)    臺南市   17        NaN     良好  0.7  0.58     0.5  5.1    18.0
# ..      ...    ...  ...        ...    ...  ...   ...     ...  ...     ...
# 77       土城    新北市   33        NaN     良好  2.3  0.41     0.3  9.7    33.0
# 78       新店    新北市   34        NaN     良好  2.2  0.45     0.3   15    37.0
# 79       萬里    新北市   38        NaN     良好  2.4  0.25     0.2   13    39.0
# 80       汐止    新北市   40        NaN     良好  2.2  0.52     0.3  4.8    32.0
# 81       基隆    基隆市   42        NaN     良好  0.5  0.46     0.3   11    34.0
#
#     ...   NO WindSpeed  WindDirec       PublishTime  PM2.5_AVG  PM10_AVG  \
# 0   ...  0.1       1.8      241.0  2020-06-04 21:00          1         5
# 1   ...  1.3       2.2      316.0  2020-06-04 21:00          7         9
# 2   ...  3.2       2.0      102.0  2020-06-04 21:00          9        24
# 3   ...  1.3       1.0      169.0  2020-06-04 21:00          3        14
# 4   ...  4.9       0.4      210.0  2020-06-04 21:00          3         7
# ..  ...  ...       ...        ...               ...        ...       ...
# 77  ...  3.4       1.0      129.0  2020-06-04 21:00         10        24
# 78  ...  3.7       2.0      174.0  2020-06-04 21:00         10        22
# 79  ...  2.3       1.1       21.0  2020-06-04 21:00         12        20
# 80  ...  9.1       1.5      123.0  2020-06-04 21:00         12        26
# 81  ...  4.2       1.1      179.0  2020-06-04 21:00         13        28
#
#     SO2_AVG   Longitude   Latitude  SiteId
# 0         1  120.124444  23.264722     310
# 1         1  120.377222  22.352222     204
# 2         1  121.383528  24.949028     203
# 3         3  120.273117  23.843139     202
# 4         1  120.245831  23.179047     201
# ..      ...         ...        ...     ...
# 77        2  121.451861  24.982528       5
# 78        2  121.537778  24.977222       4
# 79        2  121.689881  25.179667       3
# 80        2  121.642300  25.067131       2
# 81        2  121.760056  25.129167       1
#
# [82 rows x 24 columns]
