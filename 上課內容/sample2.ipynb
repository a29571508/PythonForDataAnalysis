# %%
var1 = 20
type(var1)
# Out:
# int

# %%
var1 = 20.0
type(var1)
# Out:
# float

# %%
var1 = True
type(var1)
# Out:
# bool

# %%
var1 = 'Hello'
type(var1)
# Out:
# str

# %%
var1=20 
print(type(var1))

var2=123.45
print(type(var2))

var3=True 
print(type(var3)) 

var4='string1' 
print(type(var4))
var4
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# 'string1'

# %%
var1=20 
print(type(var1))
var2=123.45
print(type(var2))
var3=True 
print(type(var3)) 
var4='string1' 
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
value1 = 100 ** 100

# %%
value1 ** 100
# Out:
# ...
