# %%
import matplotlib.pyplot as plt

data = [-1, -4.3, 15, 21, 100]
plt.figure(figsize=(8, 5))
plt.plot(data)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 2, 5, 6, 7]
y2 = [4, 5, 6, 7, 8]
plt.plot(x, y1, x, y2)
