# %%
import matplotlib.pyplot as plt

data = [-1, -4.3, 15, 21, 100]
plt.figure(figsize=(8, 5))
plt.plot(data)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 2, 5, 6, 7]
y2 = [4, 5, 6, 7, 8]
plt.plot(x, y1, x, y2)

# %%
plt.plot([1, 2, 3, 4, 5])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9 ,16],'ro')

# %%
x = [1,2,3,4,5]
y1 = [1,2,5,6,7]
y2 = [4,5,6,7,8]
plt.plot(x, y1, 'r-o', x, y2, 'g--')
plt.grid()

# %%
#axis()
plt.axis([0,5,0,20])
plt.title('My First Plot')
plt.plot()
